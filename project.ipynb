# %%
import pandas as pd
import requests

# %%
url="https://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty"

# %% [markdown]
# params={"serviceKey":"koWgnZmC9qQlZGWdQLsUa4xLHaOJvouiSiLxZ7zFZfl+rjeZYKU/4bFwYH5q9qhsxtZkG/PM2yFC8beMRQadmA==","returnType":"json","sidoName":"서울","numOfRows":"100","pageNo":"1"}  # 인증키와 요청 옵션
# response=requests.get(url,params=params)  # URL에 파라미터를 붙여 API 호출
# data=response.json()  # 응답을 JSON 형태로 변환
# items=data["response"]["body"]["items"]  # 실제 대기오염 데이터 위치
# df=pd.DataFrame(items)  # 리스트 형태 데이터를 pandas DataFrame으로 변환

# %%
params={"serviceKey":"koWgnZmC9qQlZGWdQLsUa4xLHaOJvouiSiLxZ7zFZfl+rjeZYKU/4bFwYH5q9qhsxtZkG/PM2yFC8beMRQadmA==","returnType":"json","sidoName":"전국","numOfRows":"100","pageNo":"1"}  
response=requests.get(url,params=params) 
data=response.json()

# %%
#print(response.status_code)
#print(response.text)

# %%
print(data)
# Out:
# {'response': {'body': {'totalCount': 672, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '247', 'so2Value': '0.004', 'coValue': '0.9', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '94', 'khaiGrade': '3', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.022', 'stationName': '길상', 'pm10Grade': '3', 'o3Value': '0.003'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '85', 'so2Value': '0.004', 'coValue': '0.7', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '49', 'khaiGrade': '2', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.048', 'stationName': '삼산', 'pm10Grade': '2', 'o3Value': '0.002'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '124', 'so2Value': '0.003', 'coValue': '0.7', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '88', 'khaiGrade': '3', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.029', 'stationName': '경인항', 'pm10Grade': '2', 'o3Value': '0.001'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '109', 'so2Value': '0.002', 'coValue': '0.4', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '90', 'khaiGrade': '3', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.037', 'stationName': '인천항', 'pm10Grade': '2', 'o3Value': '0.002'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '95', 'so2Value': '0.002', 'coValue': '0.4', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '42', 'khaiGrade': '2', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.041', 'stationName': '인천 신항', 'pm10Grade': '2', 'o3Value': '0.003'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '124', 'so2Value': '0.003', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '65', 'khaiGrade': '3', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.041', 'stationName': '인천 북항', 'pm10Grade': '2', 'o3Value': '0.001'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '120', 'so2Value': '0.003', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '60', 'khaiGrade': '3', 'sidoName': '인천', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.033', 'stationName': '인천 남항', 'pm10Grade': '2', 'o3Value': '0.009'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '128', 'so2Value': '0.004', 'coValue': '0.6', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '58', 'khaiGrade': '3', 'sidoName': '경기', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.040', 'stationName': '소사본동', 'pm10Grade': '2', 'o3Value': '0.004'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '212', 'so2Value': '0.003', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '65', 'khaiGrade': '3', 'sidoName': '경기', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.045', 'stationName': '내동', 'pm10Grade': '2', 'o3Value': '0.009'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '83', 'so2Value': '0.002', 'coValue': '0.6', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '79', 'khaiGrade': '2', 'sidoName': '경기', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2026-02-11 06:00', 'coGrade': '1', 'no2Value': '0.050', 'stationName': '중2동', 'pm10Grade': '2', 'o3Value': '0.001'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '128', 'so2Value': '0.003', 'coValue': '0.6', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '63', 'khaiGrade' ...

# %%
items=data["response"]["body"]["items"]  
df=pd.DataFrame(items)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   so2Grade     97 non-null     object
#  1   coFlag       3 non-null      object
#  2   khaiValue    100 non-null    object
#  3   so2Value     100 non-null    object
#  4   coValue      100 non-null    object
#  5   pm10Flag     5 non-null      object
#  6   o3Grade      97 non-null     object
#  7   pm10Value    100 non-null    object
#  8   khaiGrade    94 non-null     object
#  9   sidoName     100 non-null    object
#  10  no2Flag      2 non-null      object
#  11  no2Grade     98 non-null     object
#  12  o3Flag       3 non-null      object
#  13  so2Flag      3 non-null      object
#  14  dataTime     100 non-null    object
#  15  coGrade      97 non-null     object
#  16  no2Value     100 non-null    object
#  17  stationName  100 non-null    object
#  18  pm10Grade    95 non-null     object
#  19  o3Value      100 non-null    object
# dtypes: object(20)
# memory usage: 15.8+ KB

# %%
df.columns
# Out:
# Index(['so2Grade', 'coFlag', 'khaiValue', 'so2Value', 'coValue', 'pm10Flag',
#        'o3Grade', 'pm10Value', 'khaiGrade', 'sidoName', 'no2Flag', 'no2Grade',
#        'o3Flag', 'so2Flag', 'dataTime', 'coGrade', 'no2Value', 'stationName',
#        'pm10Grade', 'o3Value'],
#       dtype='object')

# %%
df.rename(columns={'so2Grade':'아황산가스등급','coFlag':'일산화탄소플래그','khaiValue':'통합대기환경지수','so2Value':'아황산가스농도','coValue':'일산화탄소농도','pm10Flag':'미세먼지플래그','o3Grade':'오존등급','pm10Value':'미세먼지농도','khaiGrade':'통합대기환경등급','sidoName':'시도명','no2Flag':'이산화질소플래그','no2Grade':'이산화질소등급','o3Flag':'오존플래그','so2Flag':'아황산가스플래그','dataTime':'측정시간','coGrade':'일산화탄소등급','no2Value':'이산화질소농도','stationName':'측정소명','pm10Grade':'미세먼지등급','o3Value':'오존농도'},inplace=True)

# %%
air = df.drop(columns=['일산화탄소플래그','이산화질소플래그','아황산가스플래그','미세먼지플래그','오존플래그'])
air['측정시간'] = pd.to_datetime(air['측정시간'], errors='coerce')

# %%
num_cols=[
'통합대기환경지수',
'아황산가스농도',
'일산화탄소농도',
'미세먼지농도',
'이산화질소농도',
'오존농도'
]
air[num_cols]=air[num_cols].replace(['-','', ' '], None)

# %%
air.isnull().sum()
# Out:
# 아황산가스등급     3
# 통합대기환경지수    6
# 아황산가스농도     3
# 일산화탄소농도     3
# 오존등급        3
# 미세먼지농도      5
# 통합대기환경등급    6
# 시도명         0
# 이산화질소등급     2
# 측정시간        0
# 일산화탄소등급     3
# 이산화질소농도     2
# 측정소명        0
# 미세먼지등급      5
# 오존농도        3
# dtype: int64

# %%
air[num_cols] = air[num_cols].apply(pd.to_numeric, errors='coerce')

# %%
air.describe()
# Out:
#          통합대기환경지수    아황산가스농도    일산화탄소농도     미세먼지농도  \
# count   94.000000  97.000000  97.000000  95.000000
# mean    95.659574   0.002588   0.482474  46.484211
# min     51.000000   0.001000   0.200000  16.000000
# 25%     77.000000   0.002000   0.400000  35.500000
# 50%     90.000000   0.002000   0.500000  45.000000
# 75%    109.000000   0.003000   0.600000  57.000000
# max    247.000000   0.007000   1.200000  94.000000
# std     31.353878   0.001152   0.179124  16.362167
#
#                                 측정시간    이산화질소농도       오존농도
# count                            100  98.000000  97.000000
# mean   2026-02-11 06:00:00.000000768   0.018031   0.017536
# min              2026-02-11 06:00:00   0.004000   0.001000
# 25%              2026-02-11 06:00:00   0.010250   0.004000
# 50%              2026-02-11 06:00:00   0.016000   0.013000
# 75%              2026-02-11 06:00:00   0.022000   0.028000
# max              2026-02-11 06:00:00   0.050000   0.049000
# std                              NaN   0.010211   0.014649
